# %%
import pandas as pd

# %%
products = pd.read_csv('end_to_end/datasets/products_updated.csv')
categories = pd.read_csv('end_to_end/datasets/categories_updated.csv')

# %%
categories
# Out:
#                 category_name  category_id  margin_percentage
# 0         Alcoholic Beverages            1              18.11
# 1           Bakery & Pastries            2              33.67
# 2   Beverages (Non-Alcoholic)            3              27.76
# 3         Condiments & Sauces            4              24.16
# 4                       Dairy            5              12.21
# 5                      Fruits            6              12.21
# 6            Grains & Cereals            7               9.57
# 7              Meat & Poultry            8              31.39
# 8              Non-Food Items            9              24.23
# 9              Pantry Staples           10              27.12
# 10             Prepared Foods           11               8.56
# 11                    Seafood           12              34.19
# 12     Snacks & Confectionery           13              30.48
# 13                      Soups           14              13.73
# ...

# %%
products = products[['product_id', 'resistant', 'vitality_days', 'category_id', 'cost_price', 'selling_price', 'seasonal_flag', 'demand_score', 'lead_time_days']]

# %%
products.head()
# Out:
#    product_id                product_name resistant  vitality_days  \
# 0           1         Flour - Whole Wheat   Durable            321
# 1           2  Cookie Chocolate Chip With      Weak             68
# 2           3          Onions - Cippolini      Weak            302
# 3           4  Sauce - Gravy, Au Jus, Mix   Durable            245
# 4           5      Artichokes - Jerusalem      Weak            305
#
#    category_id  reorder_levels  stock_quantity  cost_price  selling_price  \
# 0            7           400.0             644         8.9           10.6
# 1            2           300.0            2688        22.4           30.6
# 2           16           200.0            4368        17.3           18.8
# 3            4           250.0             684        14.1           17.3
# 4           16           150.0            2520         3.8            4.0
#
#    seasonal_flag  demand_score        category_name  margin_percentage  \
# ...

# %%
products['resistant'].value_counts()
# Out:
# resistant
# Durable     192
# Weak        134
# Moderate     69
# Unknown      57
# Name: count, dtype: int64
